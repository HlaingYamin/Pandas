# %%
import pandas as pd

# %%
df=pd.read_csv("Dataset/students.csv")
df
# Out:
#    Id   Name  Course    City  Session
# 0  21   Mark  Python  London  Morning
# 1  22   John  Python   Tokyo  Evening
# 2  23    Sam  Python   Paris  Morning
# 3  32  Shaun    Java   Tokyo  Morning

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of    Id   Name  Course    City  Session
# 0  21   Mark  Python  London  Morning
# 1  22   John  Python   Tokyo  Evening
# 2  23    Sam  Python   Paris  Morning
# 3  32  Shaun    Java   Tokyo  Morning>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       4 non-null      int64
#  1   Name     4 non-null      object
#  2   Course   4 non-null      object
#  3   City     4 non-null      object
#  4   Session  4 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 288.0+ bytes

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Id   Name  Course    City  Session
# 0  21   Mark  Python  London  Morning
# 1  22   John  Python   Tokyo  Evening
# 2  23    Sam  Python   Paris  Morning
# 3  32  Shaun    Java   Tokyo  Morning>

# %%
df.describe()
# Out:
#               Id
# count   4.000000
# mean   24.500000
# std     5.066228
# min    21.000000
# 25%    21.750000
# 50%    22.500000
# 75%    25.250000
# max    32.000000

# %%
#csv Reader
import csv
with open("Dataset/students.csv")as csvfile:
    reader=csv.DictReader(csvfile) #dictionary reader 
    for row in reader:
        print(row)
        print(row["Name"])
# Out:
# {'Id': '21', 'Name': 'Mark', 'Course': 'Python', 'City': 'London', 'Session': 'Morning'}
# Mark
# {'Id': '22', 'Name': 'John', 'Course': 'Python', 'City': 'Tokyo', 'Session': 'Evening'}
# John
# {'Id': '23', 'Name': 'Sam', 'Course': 'Python', 'City': 'Paris', 'Session': 'Morning'}
# Sam
# {'Id': '32', 'Name': 'Shaun', 'Course': 'Java', 'City': 'Tokyo', 'Session': 'Morning'}
# Shaun

# %%
import csv
with open("Dataset/students.csv")as csvfile:
    content=csvfile.readlines()
    for line in content:
        print(line)
        #print(type(line)) #stored as a string
        #print(type(content))
        
    header=content[:1]
    print(header)
    body=content[1:]
    print(body)
# Out:
# Id,Name,Course,City,Session
#
# 21,Mark,Python,London,Morning
#
# 22,John,Python,Tokyo,Evening
#
# 23,Sam,Python,Paris,Morning
#
# 32,Shaun,Java,Tokyo,Morning
# ['Id,Name,Course,City,Session\n']
# ['21,Mark,Python,London,Morning\n', '22,John,Python,Tokyo,Evening\n', '23,Sam,Python,Paris,Morning\n', '32,Shaun,Java,Tokyo,Morning']

# %%
import pandas as pd

# %%
df=pd.read_csv("Dataset/pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#Viewing data by data type(object)
obj_df=df.select_dtypes(include=["object"]).copy()
obj_df
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
#Viewing data by data type(int64)
obj_df=df.select_dtypes(include=["int64"]).copy()
obj_df
# Out:
#        #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      1  45      49       49       65       65     45           1
# 1      2  60      62       63       80       80     60           1
# 2      3  80      82       83      100      100     80           1
# 3      3  80     100      123      122      120     80           1
# 4      4  39      52       43       60       50     65           1
# ..   ...  ..     ...      ...      ...      ...    ...         ...
# 795  719  50     100      150      100      150     50           6
# 796  719  50     160      110      160      110    110           6
# 797  720  80     110       60      150      130     70           6
# 798  720  80     160       60      170      130     80           6
# 799  721  80     110      120      130       90     70           6
#
# [800 rows x 8 columns]

# %%
#Viewing data by data type(bool)
obj_df=df.select_dtypes(include=["bool"])
obj_df
# Out:
#      Legendary
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 795       True
# 796       True
# 797       True
# 798       True
# 799       True
#
# [800 rows x 1 columns]

# %%
#Viewing data by data type(bool)
obj_df=df.select_dtypes(include=["bool"]).copy()
obj_df
# Out:
#      Legendary
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 795       True
# 796       True
# 797       True
# 798       True
# 799       True
#
# [800 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df["Sp. Atk"]
# Out:
# 0       65
# 1       80
# 2      100
# 3      122
# 4       60
#       ...
# 795    100
# 796    160
# 797    150
# 798    170
# 799    130
# Name: Sp. Atk, Length: 800, dtype: int64

# %%
df["Type 2"].isnull().sum()
# Out:
# 386

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"].isnull().sum()
# Out:
# 0

# %%
df["Type 1"].isnull().sum()
# Out:
# 0

# %%
df["HP"].isnull().sum()
# Out:
# 0

# %%
df["Attack"].isnull().sum()
# Out:
# 0

# %%
df["Defense"].isnull().sum()
# Out:
# 0

# %%
df["Sp. Atk"].isnull().sum()
# Out:
# 0

# %%
df["Sp. Def"].isnull().sum()
# Out:
# 0

# %%
df["Speed"].isnull().sum()
# Out:
# 0

# %%
df["Generation"].isnull().sum()
# Out:
# 0

# %%
df["Legendary"].isnull().sum()
# Out:
# 0

# %%
df["Type 2"].dropna()
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 6      Flying
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 414, dtype: object

# %%
df.dropna()
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df["Type 2"].isnull().sum()
# Out:
# 386

# %%
df["Type 2"].isnull().value_counts()
# Out:
# False    414
# True     386
# Name: Type 2, dtype: int64

# %%
df["Type 2"].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"].value_counts()
# Out:
# Bulbasaur              1
# Uxie                   1
# GalladeMega Gallade    1
# Probopass              1
# Dusknoir               1
#                       ..
# Lugia                  1
# Ho-oh                  1
# Celebi                 1
# Treecko                1
# Volcanion              1
# Name: Name, Length: 800, dtype: int64

# %%
df["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df["Attack"].max()
# Out:
# 190

# %%
df[df["Attack"]==190]
# Out:
#        #                 Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True

# %%
df["Attack"]==190
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Attack, Length: 800, dtype: bool

# %%
df.iloc[160]["Attack"]==190
# Out:
# False

# %%
df[df["Name"].str.contains("Venusaur")]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df[df["Name"]==("Venusaur")]
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 2           1      False

# %%
df[df["Legendary"]==False]
# Out:
#        #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur   Grass  Poison  45      49       49       65
# 1      2                Ivysaur   Grass  Poison  60      62       63       80
# 2      3               Venusaur   Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 4      4             Charmander    Fire     NaN  39      52       43       60
# ..   ...                    ...     ...     ...  ..     ...      ...      ...
# 787  711    GourgeistSuper Size   Ghost   Grass  85     100      122       58
# 788  712               Bergmite     Ice     NaN  55      69       85       32
# 789  713                Avalugg     Ice     NaN  95     117      184       44
# 790  714                 Noibat  Flying  Dragon  40      30       35       45
# 791  715                Noivern  Flying  Dragon  85      70       80       97
#
# ...

# %%
len(df[df["Legendary"]==False])
# Out:
# 735

# %%
df[(df["HP"]>100) & (df["HP"]<200)]["Name"]
# Out:
# 44           Jigglypuff
# 45           Wigglytuff
# 96                  Muk
# 120              Rhydon
# 123          Kangaskhan
#              ...
# 753          Aromatisse
# 769             Aurorus
# 792             Xerneas
# 793             Yveltal
# 794    Zygarde50% Forme
# Name: Name, Length: 65, dtype: object

# %%
df[(df["HP"]>100) & (df["HP"]<200)][["Name","Type 1"]]
# Out:
#                  Name  Type 1
# 44         Jigglypuff  Normal
# 45         Wigglytuff  Normal
# 96                Muk  Poison
# 120            Rhydon  Ground
# 123        Kangaskhan  Normal
# ..                ...     ...
# 753        Aromatisse   Fairy
# 769           Aurorus    Rock
# 792           Xerneas   Fairy
# 793           Yveltal    Dark
# 794  Zygarde50% Forme  Dragon
#
# [65 rows x 2 columns]

# %%
df[(df["HP"]>100) & (df["HP"]<200)]["Type 1"].value_counts()
# Out:
# Normal      13
# Water        9
# Psychic      8
# Dragon       8
# Ground       5
# Fire         5
# Fighting     3
# Ghost        3
# Poison       2
# Ice          2
# Grass        2
# Dark         2
# Fairy        2
# Rock         1
# Name: Type 1, dtype: int64

# %%
df["Name"]=="Bulbasaur"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Name, Length: 800, dtype: bool

# %%
df[df["Name"]=="Bulbasaur"]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
cond1=df["Name"]=="Bulbasaur"
df.loc[cond1,["Name","Speed","Generation"]]
# Out:
#         Name  Speed  Generation
# 0  Bulbasaur     45           1

# %%
my_cond=(df["Attack"]>100) & (df["Attack"]<200)
df.loc[my_cond,["Legendary"]]=False
df.loc[my_cond,["Legendary"]]
# Out:
#      Legendary
# 7        False
# 8        False
# 12       False
# 19       False
# 39       False
# ..         ...
# 793      False
# 796      False
# 797      False
# 798      False
# 799      False
#
# [170 rows x 1 columns]

# %%
my_cond=(df["Attack"]>100) & (df["Attack"]<200)
#df.drop(["Legendary"])
df.loc[my_cond,["Legendary"]]
df
# Out:
#               #                   Name   Type 1  Type 2    HP Attack Defense  \
# 0             1              Bulbasaur    Grass  Poison    45     49      49
# 1             2                Ivysaur    Grass  Poison    60     62      63
# 2             3               Venusaur    Grass  Poison    80     82      83
# 3             3  VenusaurMega Venusaur    Grass  Poison    80    100     123
# 4             4             Charmander     Fire     NaN    39     52      43
# ...         ...                    ...      ...     ...   ...    ...     ...
# 796         719    DiancieMega Diancie     Rock   Fairy    50    160     110
# 797         720    HoopaHoopa Confined  Psychic   Ghost    80    110      60
# 798         720     HoopaHoopa Unbound  Psychic    Dark    80    160      60
# 799         721              Volcanion     Fire   Water    80    110     120
# Legendary  True                   True     True    True  True   True    True
#
# ...

# %%
my_cond=df["Type 2"].isnull()
df.loc[my_cond,["Type 2"]]="Poison"
df.loc[my_cond,["Type 2"]]
# Out:
# Empty DataFrame
# Columns: [Type 2]
# Index: []

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire  Poison  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.to_csv("Dataset/mynewfile.csv")
print("Done")
# Out:
# Done

# %%
df["newcolumn"]=df.HP+df.Attack
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire  Poison  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  newcolumn
# 0         65       65     45           1      False         94
# ...

# %%
df=df.select_dtypes(include=["int64"]).copy()
df["average"]=(df["HP"]+df["Attack"]+df["Defense"]+df["Sp. Atk"]+df["Sp. Def"]+df["Speed"])/6
df
# Out:
#        #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  newcolumn  \
# 0      1  45      49       49       65       65     45           1         94
# 1      2  60      62       63       80       80     60           1        122
# 2      3  80      82       83      100      100     80           1        162
# 3      3  80     100      123      122      120     80           1        180
# 4      4  39      52       43       60       50     65           1         91
# ..   ...  ..     ...      ...      ...      ...    ...         ...        ...
# 795  719  50     100      150      100      150     50           6        150
# 796  719  50     160      110      160      110    110           6        210
# 797  720  80     110       60      150      130     70           6        190
# 798  720  80     160       60      170      130     80           6        240
# 799  721  80     110      120      130       90     70           6        190
#
#         average
# ...

# %%
del df["newcolumn"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\first_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\first_env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\first_env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'newcolumn'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#               #                   Name   Type 1  Type 2    HP Attack Defense  \
# 0             1              Bulbasaur    Grass  Poison    45     49      49
# 1             2                Ivysaur    Grass  Poison    60     62      63
# 2             3               Venusaur    Grass  Poison    80     82      83
# 3             3  VenusaurMega Venusaur    Grass  Poison    80    100     123
# 4             4             Charmander     Fire     NaN    39     52      43
# ...         ...                    ...      ...     ...   ...    ...     ...
# 796         719    DiancieMega Diancie     Rock   Fairy    50    160     110
# 797         720    HoopaHoopa Confined  Psychic   Ghost    80    110      60
# 798         720     HoopaHoopa Unbound  Psychic    Dark    80    160      60
# 799         721              Volcanion     Fire   Water    80    110     120
# Legendary  True                   True     True    True  True   True    True
#
# ...

# %%
df.drop(["Legendary"])
df
# Out:
#               #                   Name   Type 1  Type 2    HP Attack Defense  \
# 0             1              Bulbasaur    Grass  Poison    45     49      49
# 1             2                Ivysaur    Grass  Poison    60     62      63
# 2             3               Venusaur    Grass  Poison    80     82      83
# 3             3  VenusaurMega Venusaur    Grass  Poison    80    100     123
# 4             4             Charmander     Fire     NaN    39     52      43
# ...         ...                    ...      ...     ...   ...    ...     ...
# 796         719    DiancieMega Diancie     Rock   Fairy    50    160     110
# 797         720    HoopaHoopa Confined  Psychic   Ghost    80    110      60
# 798         720     HoopaHoopa Unbound  Psychic    Dark    80    160      60
# 799         721              Volcanion     Fire   Water    80    110     120
# Legendary  True                   True     True    True  True   True    True
#
# ...

# %%
df.drop("Legendary")
# Out:
#        #                   Name   Type 1  Type 2  HP Attack Defense Sp. Atk  \
# 0      1              Bulbasaur    Grass  Poison  45     49      49      65
# 1      2                Ivysaur    Grass  Poison  60     62      63      80
# 2      3               Venusaur    Grass  Poison  80     82      83     100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80    100     123     122
# 4      4             Charmander     Fire     NaN  39     52      43      60
# ..   ...                    ...      ...     ...  ..    ...     ...     ...
# 795  719                Diancie     Rock   Fairy  50    100     150     100
# 796  719    DiancieMega Diancie     Rock   Fairy  50    160     110     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80    110      60     150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80    160      60     170
# 799  721              Volcanion     Fire   Water  80    110     120     130
#
#     Sp. Def Speed Generation  Legendary
# ...
